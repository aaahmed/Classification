# %%
#Import libraries for operations and dataframe
import numpy as np
import pandas as pd
#Import the Libraries for visualision
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Import dataset 
df=pd.read_csv('pulsar_stars.csv')

# %%
#Check data set quick view
df
# Out:
#         Mean of the integrated profile  \
# 0                           140.562500
# 1                           102.507812
# 2                           103.015625
# 3                           136.750000
# 4                            88.726562
# ...                                ...
# 17893                       136.429688
# 17894                       122.554688
# 17895                       119.335938
# 17896                       114.507812
# 17897                        57.062500
#
#         Standard deviation of the integrated profile  \
# 0                                          55.683782
# 1                                          58.882430
# 2                                          39.341649
# 3                                          57.178449
# 4                                          40.672225
# ...                                              ...
# 17893                                      59.847421
# 17894                                      49.485605
# ...

# %%
#See datatypes and missing data 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17898 entries, 0 to 17897
# Data columns (total 9 columns):
#  Mean of the integrated profile                  17898 non-null float64
#  Standard deviation of the integrated profile    17898 non-null float64
#  Excess kurtosis of the integrated profile       17898 non-null float64
#  Skewness of the integrated profile              17898 non-null float64
#  Mean of the DM-SNR curve                        17898 non-null float64
#  Standard deviation of the DM-SNR curve          17898 non-null float64
#  Excess kurtosis of the DM-SNR curve             17898 non-null float64
#  Skewness of the DM-SNR curve                    17898 non-null float64
# target_class                                     17898 non-null int64
# dtypes: float64(8), int64(1)
# memory usage: 1.2 MB

# %%
#Check stats of the dataset
df.describe()
# Out:
#         Mean of the integrated profile  \
# count                     17898.000000
# mean                        111.079968
# std                          25.652935
# min                           5.812500
# 25%                         100.929688
# 50%                         115.078125
# 75%                         127.085938
# max                         192.617188
#
#         Standard deviation of the integrated profile  \
# count                                   17898.000000
# mean                                       46.549532
# std                                         6.843189
# min                                        24.772042
# 25%                                        42.376018
# 50%                                        46.947479
# 75%                                        51.023202
# max                                        98.778911
#
#         Excess kurtosis of the integrated profile  \
# count                                17898.000000
# ...

# %%
#Check for correlation of data for future analysis
df.corr()
# Out:
#                                                 Mean of the integrated profile  \
#  Mean of the integrated profile                                       1.000000
#  Standard deviation of the integrated profile                         0.547137
#  Excess kurtosis of the integrated profile                           -0.873898
#  Skewness of the integrated profile                                  -0.738775
#  Mean of the DM-SNR curve                                            -0.298841
#  Standard deviation of the DM-SNR curve                              -0.307016
#  Excess kurtosis of the DM-SNR curve                                  0.234331
#  Skewness of the DM-SNR curve                                         0.144033
# target_class                                                         -0.673181
#
#                                                 Standard deviation of the integrated profile  \
# ...

# %% [markdown]
# ## Since all features have over 25% correlation we will include in our classification model

# %%
#let us see what the pairplot looks like
sns.pairplot(df)

# %%
#Choose arrays for regression analysis
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

# %%
# Splitting dataset into training and test arrays
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 41)

# %%
# Feature Scaling to avoid dicrepencies between inputted X values
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
#Confirm results
X_train, X_test
# Out:
# (array([[-3.61084341e-01, -5.79369015e-01,  1.74703019e-02, ...,
#           1.96427514e-02, -4.98105193e-01, -6.21488362e-01],
#         [-8.71244100e-01, -6.69614434e-01, -1.35026179e-02, ...,
#          -7.14234789e-01,  5.03355202e-01,  5.39045513e-01],
#         [ 3.14037256e-01, -7.55611008e-01, -3.89585200e-01, ...,
#          -3.80166241e-01,  2.37214636e-01, -8.00817001e-02],
#         ...,
#         [-2.56332488e+00, -2.42515494e+00,  3.93858954e+00, ...,
#           1.46462353e+00, -1.41612734e+00, -9.48567446e-01],
#         [ 1.28028595e+00,  4.59533745e-01, -4.55456466e-01, ...,
#           8.80941011e-01, -9.02363877e-01, -8.24162240e-01],
#         [-1.00168615e+00, -1.23391099e+00, -1.25473824e-02, ...,
#          -5.53020212e-01,  1.58809209e-01,  2.14481477e-03]]),
#  array([[-1.05056373e+00,  1.31946693e-01,  1.03745411e+00, ...,
#           2.34252416e+00, -1.94649100e+00, -9.84868075e-01],
#         [-4.46314624e-01,  7.10581624e-01,  3.09278759e-02, ...,
# ...

# %%
# Fitting training set to Logistic Regression
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state = 42)
classifier.fit(X_train, y_train)
# Out:
# C:\Users\Symbios\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=42, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
# Predicting the Test set results
y_pred = classifier.predict(X_test)

# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

# %%
#print results
cm
# Out:
# array([[4054,   28],
#        [  74,  319]], dtype=int64)

# %%
#Calculate Accuracy
from sklearn.metrics import classification_report
cr=classification_report(y_test, y_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      4082
#            1       0.92      0.81      0.86       393
#
#     accuracy                           0.98      4475
#    macro avg       0.95      0.90      0.92      4475
# weighted avg       0.98      0.98      0.98      4475

# %% [markdown]
# ### The model is 98% accurate
